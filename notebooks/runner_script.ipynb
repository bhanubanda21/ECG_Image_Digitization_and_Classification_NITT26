# %%
import sys
print(sys.executable)
# Out:
# C:\Users\bhanu\PycharmProjects\FYP\.venv\Scripts\python.exe

# %%
import os
import cv2
import matplotlib.pyplot as plt
from dotenv import load_dotenv

load_dotenv()

RAW_IMAGE_DIR = os.getenv("RAW_IMAGE_DIR")

def load_sample_image(index=0):
    images = sorted([f for f in os.listdir(RAW_IMAGE_DIR) if f.endswith(".png")])
    path = os.path.join(RAW_IMAGE_DIR, images[index])
    img = cv2.imread(path)
    return img, path

def show(image, title="Image"):
    plt.figure(figsize=(6,6))
    if len(image.shape) == 2:
        plt.imshow(image, cmap='gray')
    else:
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis("off")
    plt.show()

# %%
img, path = load_sample_image(0)
print("Loaded:", path)
show(img, "Original ECG")
# Out:
# Loaded: C:\Users\bhanu\Desktop\FYP Images\00000\00001_hr-0.png
